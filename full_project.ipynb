# %% [markdown]
# # 1. Testing CUDA Environment:

# %%
# !nvcc --version
# !nvidia-smi

# %%
# %%bash
# cd reference/scripts/
# ./test_cuda.sh

# %% [markdown]
# # 2. Testing Reference Code:

# %% [markdown]
# ## 2.1. Sequentiel Test:

# %%
# %%bash
# cd reference/scripts/
# ./run.sh

# %% [markdown]
# ## 2.2. PThreads Test:

# %%
# %%bash
# cd reference/scripts/
# ./run_pthreads.sh

# %% [markdown]
# ## 2.3. CUDA Test:

# %%
# %%bash
# cd reference/scripts/
# ./run_cuda.sh

# %% [markdown]
# # 3. Testing Alternative:

# %%
# %%bash
# cd alternative/
# ./run_cuda_optimized.sh
